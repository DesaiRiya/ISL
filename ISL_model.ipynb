# %% [markdown]
# <a href="https://colab.research.google.com/github/DesaiRiya/ISL/blob/main/ISL_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 23.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
# !nvidia-smi
# Out:
# Thu Feb 15 15:37:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import Image, display
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.6/78.2 GB disk)
#
# OS                  Linux-6.1.58+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# CPU                 Intel Xeon 2.20GHz
# CUDA                12.1
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.25.2>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.1.0+cu121>=1.8.0
# torchvision         ✅ 0.16.0+cu121>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.13.1>=0.11.0

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="p3qcbTKgJyBwWV5V9I0Y")
project = rf.workspace("shaafz").project("isl-yphyg")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.14, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to ISL-2 in yolov8:: 100%|██████████| 5148/5148 [00:00<00:00, 7269.69it/s]

# %%
#%cd /content/ISL-2

# !yolo task=detect mode=train model=/content/yolov8s.pt data=/content/ISL-2/data.yaml epochs=50 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/ISL-2/runs/detect/train5/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/ISL-2/runs/detect/train5/results.png', width=600)

# %%
# !yolo task=detect mode=val model=/content/ISL-2/runs/detect/train5/weights/best.pt data=/content/ISL-2/data.yaml
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11139516 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/ISL-2/valid/labels.cache... 213 images, 0 backgrounds, 0 corrupt: 100% 213/213 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 14/14 [00:05<00:00,  2.36it/s]
#                    all        213        213      0.945      0.993      0.989      0.921
#                      0        213          3      0.861          1      0.995      0.781
#                      1        213          3          1          1      0.995      0.973
#                      2        213          7      0.928          1      0.995      0.922
#                      3        213          8          1          1      0.995      0.995
#                      4        213          5          1          1      0.995      0.975
# ...

# %%
# !yolo task=detect mode=predict model=/content/ISL-2/runs/detect/train5/weights/best.pt conf=0.25 source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11139516 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/111 /content/ISL-2/test/images/0-1-_jpeg.rf.56c785389cbe516056fa81c7889da9a2.jpg: 640x640 1 0, 16.4ms
# image 2/111 /content/ISL-2/test/images/0-10-_jpeg.rf.55b6d4753b90f45b11058e1c8946472a.jpg: 640x640 1 0, 16.5ms
# image 3/111 /content/ISL-2/test/images/0-18-_jpeg.rf.28e3db49eecb278a9655f935205bd1e7.jpg: 640x640 1 0, 16.4ms
# image 4/111 /content/ISL-2/test/images/0-26-_jpeg.rf.cafcf25679d4077187b60016a097623e.jpg: 640x640 1 0, 16.4ms
# image 5/111 /content/ISL-2/test/images/0-6-_jpeg.rf.957a65e227ef4e4b8a8c81dd36e979a4.jpg: 640x640 1 0, 16.4ms
# image 6/111 /content/ISL-2/test/images/2-2-_jpg.rf.e5f39906ce132747fa0c4aabcfbe1a26.jpg: 640x640 1 2, 16.4ms
# image 7/111 /content/ISL-2/test/images/2-30-_jpg.rf.8717224a154d53dbc3ea35ea9ba3383f.jpg: 640x640 1 2, 15.7ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/ISL-2/runs/detect/predict2/*.jpg')[:5]:
  display(Image(filename=image_path,height=400))
  print("\n")
